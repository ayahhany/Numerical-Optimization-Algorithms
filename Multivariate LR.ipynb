# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
multiple = np.loadtxt("./resources/MultipleLR.csv", delimiter = ",")

# %%
multiple
# Out:
# array([[ 73.,  80.,  75., 152.],
#        [ 93.,  88.,  93., 185.],
#        [ 89.,  91.,  90., 180.],
#        [ 96.,  98., 100., 196.],
#        [ 73.,  66.,  70., 142.],
#        [ 53.,  46.,  55., 101.],
#        [ 69.,  74.,  77., 149.],
#        [ 47.,  56.,  60., 115.],
#        [ 87.,  79.,  90., 175.],
#        [ 79.,  70.,  88., 164.],
#        [ 69.,  70.,  73., 141.],
#        [ 70.,  65.,  74., 141.],
#        [ 93.,  95.,  91., 184.],
#        [ 79.,  80.,  73., 152.],
#        [ 70.,  73.,  78., 148.],
#        [ 93.,  89.,  96., 192.],
#        [ 78.,  75.,  68., 147.],
#        [ 81.,  90.,  93., 183.],
#        [ 88.,  92.,  86., 177.],
#        [ 78.,  83.,  77., 159.],
#        [ 82.,  86.,  90., 177.],
#        [ 86.,  82.,  89., 175.],
#        [ 78.,  83.,  85., 175.],
#        [ 76.,  83.,  71., 149.],
#        [ 96.,  93.,  95., 192.]])

# %%
X0 = np.ones(len(multiple))
X1 = multiple[:, 0]
X2 = multiple[:,1]
X3 = multiple[:,2]
y = multiple[:,3]
y = y.reshape(25,1)

# %%
np.matrix([X0,X1,X2,X3]).T.shape
# Out:
# (25, 4)

# %%
def multivariate_LR(x0,x1,x2,x3,y,alpha):
    #1. assume thetas = 0
    thetas = np.zeros(4).reshape(4,1)
    thetas_lst=np.zeros((100,4))
    js =np.zeros(100)


    #2. x matrix
    X = np.matrix([x0,x1,x2,x3]).T
    for i in range(100):
        #if i> 0 : print(gradients.shape)
        #3. calculate the hypothesis
        hx = (np.dot(X,thetas)).reshape(25,1)
        
        #4. calculate loss/cost function
        e = (hx - y).reshape(25,1)
        #print(e)
        j =(1/(len(y)*2))* np.sum(np.square(e))
        #print(j)
        thetas_lst[i,:]=thetas.reshape(1,4)
        js[i] = j
      
        #gradient=((np.dot(x.T,e))/m).reshape(n,1)

        #5. calculate the gradient
        gradients = ((np.dot(X.T, e))/len(y)).reshape(4,1)
        
        #6. Update the parameters (simultaneously)
        thetas = thetas - alpha * gradients
    js = js.reshape(25,4)
    return thetas_lst, js

# %%
thetas, js = multivariate_LR(X0,X1,X2,X3,y,0.0001)

# %%
print(f'''the min cost is {js[-1]}''')
# Out:
# the min cost is [10.02043665  9.6171356   9.24509855  8.90186095]

# %%
plt.plot(np.arange(len(js)), js,'-o')
plt.xlabel("Epochs")
plt.ylabel("J")
plt.title("Epochs vs Cost function")
# Out:
# Text(0.5, 1.0, 'Epochs vs Cost function')

# %%
js = js.reshape(100,1)

# %%
plt.plot(np.arange(len(js)), js,'-o')
plt.xlabel("Epochs")
plt.ylabel("J")
plt.title("Epochs vs Cost function")
# Out:
# Text(0.5, 1.0, 'Epochs vs Cost function')

# %%
# theta 0
plt.plot(thetas[:,0],js, '-o')
plt.xlabel("theta 0")
plt.ylabel("J")
plt.title("theta 0 vs cost function")
# Out:
# Text(0.5, 1.0, 'theta 0 vs cost function')

# %%
# theta 1
plt.plot(thetas[:,1],js, '-o')
plt.xlabel("theta 1")
plt.ylabel("J")
plt.title("theta 1 vs cost function")
# Out:
# Text(0.5, 1.0, 'theta 1 vs cost function')

# %%
# theta 2
plt.plot(thetas[:,2],js, '-o')
plt.xlabel("theta 2")
plt.ylabel("J")
plt.title("theta 2 vs cost function")
# Out:
# Text(0.5, 1.0, 'theta 2 vs cost function')

# %%
# theta 3
plt.plot(thetas[:,3],js, '-o')
plt.xlabel("theta 3")
plt.ylabel("J")
plt.title("theta 3 vs cost function")
# Out:
# Text(0.5, 1.0, 'theta 3 vs cost function')
